# %% [markdown]
# # Credit Risk Analysis

# %% [markdown]
# ## Import packages

# %% [markdown]
# 1. `sys`: System-specific parameters and functions.
# 2. `reload` (from `imp`): Reload previously imported modules.
# 3. `matplotlib.pyplot`: Data visualization.
# 4. `numpy`: Numerical computing.
# 5. `pandas`: Data manipulation and analysis.
# 6. `seaborn`: Statistical data visualization.
# 7. `SimpleImputer` (from `sklearn.impute`): Handling missing data.
# 8. `LogisticRegression` (from `sklearn.linear_model`): Logistic regression for classification.

# %%
import sys
sys.path.append("..")
from imp import reload
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from helper_functions import utils_data, utils_metrics, utils_models, utils_plot
from helper_functions import config
from structure import eda_info

# Ignore warnings
import warnings
warnings.filterwarnings('ignore', category = FutureWarning)

# %%
reload(eda_info)
# Out:
# <module 'structure.eda_info' from '/home/chris/Learning-2023/anyoneai_dir/endproj/credit-risk-analysis_chris/src/notebooks/../structure/eda_info.py'>

# %% [markdown]
# #### GET DATA

# %%
# Import data set
app_train, app_test, columns_description = utils_data.get_datasets()
# Out:
# /home/chris/Learning-2023/anyoneai_dir/endproj/credit-risk-analysis_chris/src/notebooks/../helper_functions/utils_data.py:59: DtypeWarning: Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   app_train = pd.read_csv(config.DATASET_TRAIN, delimiter='\t', encoding='latin1', header=None)

# %% [markdown]
# #### EDA_INFO

# %%
print("EDA_INFO")
eda_info.get_info_from_data(app_train, app_test, columns_description)
# Out:
# EDA_INFO
# Data dimension: 50000 rows and 54 columns
# Data dimension: 20000 rows and 53 columns
#    Value  Count  Percentage
# 0      0  36959      73.918
# 1      1  13041      26.082
# +----------------------+---------------+
# |        Column        | Missing Count |
# +----------------------+---------------+
# |    RESIDENCE_TYPE    |     1349      |
# | MONTHS_IN_RESIDENCE  |     3777      |
# |  PROFESSIONAL_CITY   |     33783     |
# | PROFESSIONAL_BOROUGH |     33783     |
# |   PROFESSION_CODE    |     7756      |
# |   OCCUPATION_TYPE    |     7313      |
# | MATE_PROFESSION_CODE |     28884     |
# | MATE_EDUCATION_LEVEL |     32338     |
# +----------------------+---------------+
# +----+--------------------------------+-------------+-----------------------------------+
# |    |          Feature Name          | UniqueCount |             RangeMeta             |
# +----+--------------------------------+-------------+-----------------------------------+
# | 0  |           ID_CLIENT            |    50000    | 1-50000, 50001-70000, 70001-90000 |
# | 1  |          PAYMENT_DAY           |      6      |          1,5,10,15,20,25          |
# | 2  |     QUANT_ADDITIONAL_CARDS     |      1      |             1,2,NULL              |
# | 3  |      POSTAL_ADDRESS_TYPE       |      2      |                1.2                |
# | 4  |         MARITAL_STATUS         |      8      |           1,2,3,4,5,6,7           |
# | 5  |        QUANT_DEPENDANTS        |     17      |           0, 1, 2, ...            |
# | 6  |        EDUCATION_LEVEL         |      1      |             1,2,3,4,5             |
# | 7  |          NACIONALITY           |      3      |              0, 1, 2              |
# | 8  |         RESIDENCE_TYPE         |      7      |          1,2,3,4,5,NULL           |
# | 9  |      MONTHS_IN_RESIDENCE       |     89      |          1,2,... , NULL           |
# | 10 |           FLAG_EMAIL           |      2      |                0.1                |
# | 11 |    PERSONAL_MONTHLY_INCOME     |    5495     |                nan                |
# | 12 |         OTHER_INCOMES          |     615     |                nan                |
# | 13 |           FLAG_VISA            |      2      |                0.1                |
# | 14 |        FLAG_MASTERCARD         |      2      |                0.1                |
# | 15 |          FLAG_DINERS           |      2      |                0.1                |
# | 16 |     FLAG_AMERICAN_EXPRESS      |      2      |                0.1                |
# | 17 |        FLAG_OTHER_CARDS        |      2      |             0,1,NULL              |
# | 18 |     QUANT_BANKING_ACCOUNTS     |      3      |               0,1,2               |
# | 19 | QUANT_SPECIAL_BANKING_ACCOUNTS |      3      |               0,1,2               |
# | 20 |     PERSONAL_ASSETS_VALUE      |     153     |                nan                |
# | 21 |           QUANT_CARS           |      2      |                nan                |
# | 22 |       MONTHS_IN_THE_JOB        |     21      |                nan                |
# | 23 |        PROFESSION_CODE         |     20      |             1,2,3,...             |
# | 24 |        OCCUPATION_TYPE         |      7      |          1,2,3,4,5,NULL           |
# | 25 |      MATE_PROFESSION_CODE      |     19      |             1,2,3,...             |
# | 26 |      MATE_EDUCATION_LEVEL      |      7      |             1,2,3,4,5             |
# | 27 |   FLAG_HOME_ADDRESS_DOCUMENT   |      1      |                0.1                |
# | 28 |            FLAG_RG             |      1      |                0.1                |
# | 29 |            FLAG_CPF            |      1      |                0.1                |
# | 30 |       FLAG_INCOME_PROOF        |      1      |                0.1                |
# | 31 |            PRODUCT             |      3      |               1,2,7               |
# | 32 |              AGE               |     89      |                nan                |
# | 33 |       TARGET_LABEL_BAD=1       |      2      |                nan                |
# +----+--------------------------------+-------------+-----------------------------------+

# %% [markdown]
# #### EDA_CLEANING

# %%
print("EDA_CLEANING")
# Out:
# EDA_CLEANING

# %% [markdown]
# #### EDA_INFO

# %%
print("EDA_PREPROCESSING")
# Out:
# EDA_PREPROCESSING
